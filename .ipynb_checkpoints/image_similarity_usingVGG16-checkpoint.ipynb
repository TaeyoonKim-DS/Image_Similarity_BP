# %%
# !pip install opencv-python-headless
# Out:
# Requirement already satisfied: opencv-python-headless in /home/studio-lab-user/.conda/envs/d2l/lib/python3.9/site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.17.3 in /home/studio-lab-user/.conda/envs/d2l/lib/python3.9/site-packages (from opencv-python-headless) (1.22.4)

# %%
from keras.applications.vgg16 import VGG16
import cv2

# %%
path = "/home/studio-lab-user/Personal_Codes/Image_similarity"

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import glob

# Load the VGG16 model
vgg16_model = VGG16(weights='imagenet', include_top=False, pooling='avg')

prediction_images = glob.glob(path + "/prediction_images/*")
test_images = glob.glob(path + "/reference_images/*")

# %%
import glob
from PIL import Image

reference_images = glob.glob(path + "/reference_images/*")
for reference_image in reference_images:
    image_show = Image.open(reference_image)
    image_show.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1303x656>

# %%
for test_img in test_images:
    test_image = cv2.imread(test_img)

    img2 = preprocess_input(test_image)
    img2 = np.expand_dims(img2, axis=0)
    img2_features = vgg16_model.predict(img2)
    img2_features = np.ravel(img2_features)

    for prediction_img in prediction_images:
        prediction_image = cv2.imread(prediction_img)
        img1 = preprocess_input(prediction_image)
        img1 = np.expand_dims(img1, axis=0)
        img1_features = vgg16_model.predict(img1)
        img1_features = np.ravel(img1_features)
        
        similarity = cosine_similarity(img1_features.reshape(1, -1), img2_features.reshape(1, -1))
        print(prediction_img[-20:], test_img[-20:], similarity)
# Out:
# 1/1 [==============================] - 5s 5s/step
# [ WARN:0@313.757] global loadsave.cpp:244 findDecoder imread_('/home/studio-lab-user/Personal_Codes/Image_similarity/prediction_images/swoop_image_after_click'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
#       9 for prediction_img in prediction_images:
#      10     prediction_image = cv2.imread(prediction_img)
# ---> 11     img1 = preprocess_input(prediction_image)
#      12     img1 = np.expand_dims(img1, axis=0)
#      13     img1_features = vgg16_model.predict(img1)
#
# File ~/.conda/envs/d2l/lib/python3.9/site-packages/keras/applications/vgg16.py:257, in preprocess_input(x, data_format)
#     255 @keras_export("keras.applications.vgg16.preprocess_input")
#     256 def preprocess_input(x, data_format=None):
# --> 257     return imagenet_utils.preprocess_input(
#     258         x, data_format=data_format, mode="caffe"
#     259     )
#
# File ~/.conda/envs/d2l/lib/python3.9/site-packages/keras/applications/imagenet_utils.py:123, in preprocess_input(x, data_format, mode)
#     121     return _preprocess_numpy_input(x, data_format=data_format, mode=mode)
#     122 else:
# --> 123     return _preprocess_symbolic_input(x, data_format=data_format, mode=mode)
#
# File ~/.conda/envs/d2l/lib/python3.9/site-packages/keras/applications/imagenet_utils.py:287, in _preprocess_symbolic_input(x, data_format, mode)
#     284         x = x[:, ::-1, ...]
#     285 else:
#     286     # 'RGB'->'BGR'
# --> 287     x = x[..., ::-1]
#     288 mean = [103.939, 116.779, 123.68]
#     289 std = None
#
# TypeError: 'NoneType' object is not subscriptable
